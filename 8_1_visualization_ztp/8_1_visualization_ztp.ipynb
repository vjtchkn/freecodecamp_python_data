# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### Line Chart

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples);

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(years, yield_apples)
plt.xlabel("year")
plt.ylabel("Yield (tons per hectare)");

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]

# %%
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)");

# %%
plt.plot(years, apples)
plt.plot(years, oranges)

plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)")

plt.title("Crop Yields in Kanto")
plt.legend(["Apples", "Oranges"]);

# %% [markdown]
# ### Markers and Styling

# %%
plt.plot(years, apples, marker="o")
plt.plot(years, oranges, marker="x")

plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)")

plt.title("Crop Yields in Kanto")
plt.legend(["Apples", "Oranges"]);

# %%
plt.figure(figsize=(8, 4))

plt.plot(years, apples, marker="s", color="b", linestyle="-")
plt.plot(years, oranges, marker="o", color="r", linestyle="--")

plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)")

plt.title("Crop Yields in Kanto")
plt.legend(["Apples", "Oranges"]);

# %% [markdown]
# ### Seaborn library

# %%
sns.set_style("whitegrid")

# %%
plt.plot(years, apples, marker="o")
plt.plot(years, oranges, marker="o")

plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)")

plt.title("Crop Yields in Kanto")
plt.legend(["Apples", "Oranges"]);

# %%
sns.set_style("darkgrid")

# %%
plt.plot(years, apples, marker="o")
plt.plot(years, oranges, marker="o")

plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)")

plt.title("Crop Yields in Kanto")
plt.legend(["Apples", "Oranges"]);

# %% [markdown]
# ### Scatter Plot

# %%
flowers_df = sns.load_dataset("iris")
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length,
                y=flowers_df.sepal_width,
                hue=flowers_df.species);

# %%
plt.figure(figsize=(8, 4))
plt.title("Sepal Dimensions")

sns.scatterplot(x=flowers_df.sepal_length,
                y=flowers_df.sepal_width,
                hue=flowers_df.species);

# %%
plt.title("Sepal Dimensions")

sns.scatterplot(x="sepal_length",
                y="sepal_width",
                hue=flowers_df.species,
                data=flowers_df);

# %% [markdown]
# ### Histogram

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width);

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width, bins=5);

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width, bins=np.arange(2, 5, 0.25));

# %%
sns.histplot(data=flowers_df, x="sepal_width", hue="species")
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=flowers_df, x="sepal_width", hue="species", multiple="stack")
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='Count'>

# %% [markdown]
# ### Bar chart

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, oranges)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.plot(years, oranges, color="orange", marker="o")
plt.bar(years, oranges);

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples);

# %%
fruit_df = pd.DataFrame({"year": years, "apples": apples, "oranges":oranges})
fruit_df
# Out:
#    year  apples  oranges
# 0  2000    0.35      0.4
# 1  2001    0.60      0.8
# 2  2002    0.90      0.9
# 3  2003    0.80      0.7
# 4  2004    0.65      0.6
# 5  2005    0.80      0.8

# %%
fruit_df = pd.melt(fruit_df, id_vars="year", value_vars=["apples", "oranges"])
fruit_df
# Out:
#     year variable  value
# 0   2000   apples   0.35
# 1   2001   apples   0.60
# 2   2002   apples   0.90
# 3   2003   apples   0.80
# 4   2004   apples   0.65
# 5   2005   apples   0.80
# 6   2000  oranges   0.40
# 7   2001  oranges   0.80
# 8   2002  oranges   0.90
# 9   2003  oranges   0.70
# 10  2004  oranges   0.60
# 11  2005  oranges   0.80

# %%
sns.barplot(data=fruit_df, x="year", y="value", hue="variable")
# Out:
# <AxesSubplot: xlabel='year', ylabel='value'>

# %%
sns.barplot(data=fruit_df, x="year", y="value", hue="variable")
# Out:
# <AxesSubplot: xlabel='year', ylabel='value'>

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
bill_avg_df = tips_df.groupby("day")[["total_bill"]].mean()
bill_avg_df
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(bill_avg_df.index, bill_avg_df.total_bill)
# Out:
# <BarContainer object of 4 artists>

# %%
sns.barplot(data=tips_df, x="day", y="total_bill")
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips_df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="day", y="total_bill", hue="smoker", data=tips_df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Heatmap

# %%
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
flights_df
# Out:
# C:\Users\vjtch\AppData\Local\Temp\ipykernel_7432\1940392331.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# ...

# %%
plt.title("No. of Passangers (1000s)")
sns.heatmap(flights_df, cmap="Blues");

# %% [markdown]
# ### Plotting multiple charts in a grid

# %%
fig, axes = plt.subplots(2,3)

axes[0,0].plot(years, oranges, "o--r")
axes[0,0].set_title("Yield of oranges")

plt.tight_layout(pad=2)
